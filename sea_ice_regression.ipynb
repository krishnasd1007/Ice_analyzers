# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
path = '/gdrive/My Drive/AI_climate_sea-ice_challenge/'
data = pd.read_csv(path + 'DRIFT_DATA_TRAIN.csv')

# %%
data = data.drop(columns=['year','month','day','doy','h_cs2smos','id_buoy'])
data['Ui'] = np.sqrt((data['u_buoy']*data['u_buoy'])+(data['v_buoy']*data['v_buoy']))
data['Uw'] = np.sqrt((data['x_EASE']*data['x_EASE'])+(data['y_EASE']*data['y_EASE']))
data['Ua'] = np.sqrt((data['u_ERA5']*data['u_ERA5'])+(data['v_ERA5']*data['v_ERA5']))
data.head()
# Out:
#        x_EASE      y_EASE    u_buoy  ...        Ui          Uw        Ua
# 0  147.506958  138.582672 -0.797554  ...  1.370671  202.394317  6.711849
# 1  146.834778  120.509880  0.643200  ...  0.741408  189.955477  6.851881
# 2  130.993561  129.623672 -1.162420  ...  1.187695  184.286759  8.896751
# 3  147.524719  157.382492  0.919766  ...  0.920127  215.714607  1.496117
# 4  147.470963  138.599823  0.380940  ...  1.300527  202.379830  3.338513
#
# [5 rows x 12 columns]

# %%
data.isnull().sum(axis = 0)
# Out:
# x_EASE      0
# y_EASE      0
# u_buoy      0
# v_buoy      0
# u_ERA5      0
# v_ERA5      0
# sic_CDR     0
# h_piomas    0
# d2c         0
# Ui          0
# Uw          0
# Ua          0
# dtype: int64

# %%
x = data['Ua']
y = data['Ui']

# %%
x.head()
# Out:
# 0    6.711849
# 1    6.851881
# 2    8.896751
# 3    1.496117
# 4    3.338513
# Name: Ua, dtype: float64

# %%
y.head()
# Out:
# 0    1.370671
# 1    0.741408
# 2    1.187695
# 3    0.920127
# 4    1.300527
# Name: Ui, dtype: float64

# %%
x = np.array(x)
y = np.array(y)
y = np.reshape(y,(-1,1))
x = np.reshape(x,(-1,1))

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression().fit(x,y)

# %%
pred_ui = model.predict(x)

# %%
score = model.score(x,y)
print('train model score : {} %'.format(score*100))
# Out:
# train model score : 32.48358577890832 %
